# %% [markdown]
# <a href="https://colab.research.google.com/github/MeyWhy/youtube_scraper/blob/main/youtube_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Youtube Scaper to reorganize my "à regarder plus tard" playlist into multiple categorized playlists

# %% [markdown]
# possible things used:
# - webscraping libs (websoup, selenium etc.)
# - youtube api
# - regex
# - nlp ?
# -

# %% [markdown]
# steps possibly needed to make this come true:
# 1- auth phase (if using ytb api)
# 2- access "à regarder plus tard" playlist
# 3- call functions to check for 100 videos to which cat they belong
# 4- create/insert the videos into the correct category-playlist
# 5- done ?

# %%
#importing step
import numpy as np

# %%
categories = ["litterature", "network", "cinema", "music", "philosophy",
              "commentary", "lord of the ring", "diy", "tips", "politics",
              "economy", "computer science", "physics", "mathematics", "makeup",
              "vlog", "storytime", "cooking", "programming"]
